# %%
from nltk.tokenize import sent_tokenize

# %%
corpus = """
Hello welcom to shivam sharma hindi! youtube's channel.
please do subscribe the channel
"""

# %%
sent_tokenize(corpus)
# Out:
# ['\nHello welcom to shivam sharma hindi!',
#  "youtube's channel.",
#  'please do subscribe the channel']

# %%
# paragraph to word
from nltk.tokenize import word_tokenize

word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcom',
#  'to',
#  'shivam',
#  'sharma',
#  'hindi',
#  '!',
#  'youtube',
#  "'s",
#  'channel',
#  '.',
#  'please',
#  'do',
#  'subscribe',
#  'the',
#  'channel']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcom',
#  'to',
#  'shivam',
#  'sharma',
#  'hindi',
#  '!',
#  'youtube',
#  "'",
#  's',
#  'channel',
#  '.',
#  'please',
#  'do',
#  'subscribe',
#  'the',
#  'channel']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()

tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcom',
#  'to',
#  'shivam',
#  'sharma',
#  'hindi',
#  '!',
#  'youtube',
#  'channel.',
#  'please',
#  'do',
#  'subscribe',
#  'the',
#  'channel']
