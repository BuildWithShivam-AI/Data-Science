# %% [markdown]
# ## Measure of Variability
# - Range
# - (MAD) Mean Absolute Deviation
# - Varience
# - STD (Standerd Devation)
#
# It Help to identify the data spredness and how data wast.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Range
# - Range is between the min and max value is the dataset.
#
# Range = Min - max

# %%
data = pd.read_csv("Titanic-Dataset.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#
min_r = data["Age"].min()

# %%
max_r = data["Age"].max()

# %%
min_r,max_r
# Out:
# (np.float64(0.42), np.float64(80.0))

# %%
range = max_r - min_r
range
# Out:
# np.float64(79.58)

# %% [markdown]
# ### MAD (Mean Absolution Deviation) - formula
#
# - MAD Formula
#
# ![image.png](attachment:image.png)
# - this mean's the dataset is the average distance between each data point and the mean
# - It's help me to identify the variability in a dataset
#
# - where :
#   * $\sum$ = Sum of all calculated values
#   * $|x_i - \bar{x}|$ = The absolute difference between each data point ($x_i$) and the dataset mean ($\bar{x}$)
#   * $n$ = The total number of data points

# %%
sec_a = np.array([75,65,73,68,72,67])
sec_b = np.array([90,47,43,96,93,51])
no = np.array([1,2,3,4,5,6])
mean = np.mean(sec_a)
#mean of both colum have same data

# %%
plt.Figure(figsize=(12,3))
plt.scatter(x=sec_a,y=no,label ="Session A")
plt.scatter(x=sec_b,y=no,label ="Session B")
plt.plot([70,70,70,70,70,70],no,color = "red",label = "Mean")
plt.legend()
plt.show()

# %%
mad_a = np.sum(np.abs(sec_a-mean))/len(sec_a)
mad_b = np.sum(np.abs(sec_b-mean))/len(sec_b)
mad_a,mad_b
# Out:
# (np.float64(3.3333333333333335), np.float64(23.0))

# %% [markdown]
# ### Standard Deviation & Variance
# - formula of STD ==>
#
# ![alt text](image.png)
#
# * $\sum$ : Sum of all calculated values
# * $x_i$ : Each individual data point
# * $\mu$ : Population mean
# * $N$ : Total number of data points (Population)
# * $\sigma$ : Population standard deviation
#
#
# - formula of Varience ==>
#
# ![image.png](attachment:image.png)

# %%
np.std(sec_a), np.std(sec_b)
# Out:
# (np.float64(3.559026084010437), np.float64(23.18045153428495))

# %%
np.var(sec_a), np.var(sec_b)
# Out:
# (np.float64(12.666666666666666), np.float64(537.3333333333334))

# %%
# checking on how to analyssis on single column
# if Data of MAD and STD and near by 0 to 10 to 15 or near by then it fine to select else this data is wast range of data.

# like 

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data["Age"].std(), data["Age"].var()
# Out:
# (np.float64(14.526497332334042), np.float64(211.01912474630802))

# %%
sns.histplot(x="Age",data =data)
plt.show()
