# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # pandas DataFrames

# %%
data = pd.read_csv("data.csv")
data.head
# Out:
# <bound method NDFrame.head of    age   first last name
# 0   32  shivam    sharma
# 1   24   suman     singh
# 2   31    shiv     kumar>

# %%
data = np.random.randint(2,10,(5,3))

# %%
data_dataframe  = pd.DataFrame(data,columns=["col1","col2","col3"])

# %%
data_dataframe.head()
# Out:
#    col1  col2  col3
# 0     6     4     9
# 1     6     2     8
# 2     5     2     4
# 3     3     6     9
# 4     5     3     8

# %%
df = data_dataframe.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    5 non-null      int32
#  1   col2    5 non-null      int32
#  2   col3    5 non-null      int32
# dtypes: int32(3)
# memory usage: 192.0 bytes

# %%
df.describe()
# Out:
#            col1     col2      col3
# count  5.000000  5.00000  5.000000
# mean   5.000000  3.40000  7.600000
# std    1.224745  1.67332  2.073644
# min    3.000000  2.00000  4.000000
# 25%    5.000000  2.00000  8.000000
# 50%    5.000000  3.00000  8.000000
# 75%    6.000000  4.00000  9.000000
# max    6.000000  6.00000  9.000000

# %%
data_natest = pd.DataFrame(np.random.randint(2,20,(5,3)),columns=["Col1","Col2","Col3"])
data_natest
# Out:
#    Col1  Col2  Col3
# 0    10     8    14
# 1     9     8    19
# 2    17    17     4
# 3    19    18    12
# 4     9     4    12

# %%
data_natest.isnull().sum() == 0
# Out:
# Col1    True
# Col2    True
# Col3    True
# dtype: bool

# %%
data_natest.iloc[1:2,1:2] = np.nan

# %%
data_natest
# Out:
#    Col1  Col2  Col3
# 0    10   8.0    14
# 1     9   NaN    19
# 2    17  17.0     4
# 3    19  18.0    12
# 4     9   4.0    12

# %%
data_natest.isnull().sum()
# Out:
# Col1    0
# Col2    1
# Col3    0
# dtype: int64

# %%
data_natest.value_counts()
# Out:
# Col1  Col2  Col3
# 9     4.0   12      1
# 10    8.0   14      1
# 17    17.0  4       1
# 19    18.0  12      1
# Name: count, dtype: int64

# %%
data_natest['Col1'].unique()
# Out:
# array([10,  9, 17, 19], dtype=int32)

# %%
import requests
from io import StringIO

url = "https://en.wikipedia.org/wiki/Mobile_country_code"

# Add browser header
headers = {
    "User-Agent": "Mozilla/5.0"
}

# Get webpage content
response = requests.get(url, headers=headers)

html_data = pd.read_html(StringIO(response.text))

# %%
html_data[0]
# Out:
#    MCC  MNC Brand      Operator       Status Bands (MHz)  \
# 0    1    1  TEST  Test network  Operational         any
# 1    1    1  TEST  Test network  Operational         any
# 2  999   99   NaN  Internal use  Operational         any
# 3  999  999   NaN  Internal use  Operational         any
#
#                               References and notes
# 0                                              NaN
# 1                                              NaN
# 2  Internal use in private networks, no roaming[6]
# 3  Internal use in private networks, no roaming[6]

# %%
#pickling and Unpickling

import seaborn as sns
df = sns.load_dataset("flights")

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
import pickle
filename = "file.pk1"

# %%
#pickel and serialize process   
pickle.dump(df,open(filename,'wb'))

# %%
#unpickel and unserialize process

pickle.load(open(filename,'rb'))
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
