# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Titanic-Dataset.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Probability
#
# ##### Random Variables
# - Type of random variable
#     * Discrit Random Variable : this work on fixed number like (1,2,3,4,5,6) this number only visible
#     * Continues Random Variable : It's work on range value (1 to 6) but i can get number 1.5, 2.5 any value.
#
# ##### Probability : Assumption
# - Formula :-
#     * P(A) = Number of time (A) / Total Number of Possible outcome
# -

# %% [markdown]
# #### Normal Distribution Function
# It also know as Gaussion distribution, this is a symmetrical about the mean, this appear as bell curve.
# - Formula ==>
#
# ![image.png](attachment:image.png)
#
# * Where :
#
#   ![alt text](image.png)

# %% [markdown]
# #### Standerd Normal Distribution
# - This asme like Normal distribution but one things is change is alway center align an mean will a 0 like
# - Mean = 0 and STD = 1
# - It also know as Z distribution or Z-Score.
#
# ![image.png](attachment:image.png)
