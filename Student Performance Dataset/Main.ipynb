# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("student_performance.csv")
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   student_id               1000000 non-null  int64
#  1   weekly_self_study_hours  1000000 non-null  float64
#  2   attendance_percentage    1000000 non-null  float64
#  3   class_participation      1000000 non-null  float64
#  4   total_score              1000000 non-null  float64
#  5   grade                    1000000 non-null  str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 45.8 MB
# None

# %%
summary = pd.DataFrame({
    "Min": data.min(numeric_only=False),
    "Max": data.max(numeric_only=False)
})

summary = summary.reset_index()
summary.columns = ["Column Name", "Min", "Max"]
print(summary)
# Out:
#                Column Name   Min      Max
# 0               student_id     1  1000000
# 1  weekly_self_study_hours   0.0     40.0
# 2    attendance_percentage  50.0    100.0
# 3      class_participation   0.0     10.0
# 4              total_score   9.4    100.0
# 5                    grade     A        F

# %% [markdown]
# ##Regression Tasks
# Predict total_score from weekly_self_study_hours.
# Train and evaluate Linear Regression models.
# Extend to multiple regression using attendance_percentage and class_participation.
#
# You are being asked to answer:
#
# 👉 “Can student behavior predict exam score?”
#
# Using:
#
# study time
# attendance
# participation

# %%
x= data[['weekly_self_study_hours']]
y = data['total_score']

model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[10]])

print(prediction)
# Out:
# [75.14662844]
# d:\Code_Expo\Data Science\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x, y)

# %%
y_pred = model.predict(x)

# %%
plt.plot(x, y_pred)
plt.xlabel("Weekly Self Study Hours")
plt.ylabel("Total Score")
plt.title("Study Hours vs Total Score")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(x, y, label="Actual Data")
plt.plot(x, y_pred, label="Regression Line")

plt.legend()

plt.xlabel("Study Hours")
plt.ylabel("Score")

plt.show()
