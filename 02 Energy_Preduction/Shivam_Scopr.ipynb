# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
data = pd.read_csv("Energy_Dataset_ML.csv")
data.head()
# Out:
#                Time  feature_01  feature_02  feature_03  feature_04  \
# 0  04/10/2024 12:00         0.0         0.0         0.0  119.290878
# 1  04/10/2024 12:15         0.0         0.0         0.0  119.224632
# 2  04/10/2024 12:30         0.0         0.0         0.0  119.294258
# 3  04/10/2024 12:45         0.0         0.0         0.0  119.451820
# 4  04/10/2024 13:00         0.0         0.0         0.0  119.407585
#
#    feature_05  feature_06  feature_07  feature_08  feature_09  ...  \
# 0         0.0         0.0  108.502075  134.461426  100.306824  ...
# 1         0.0         0.0    0.173611    0.404006    0.115741  ...
# 2         0.0         0.0  100.112236  109.554970    0.115741  ...
# 3         0.0         0.0   95.328934  137.838760   70.482636  ...
# 4         0.0         0.0   85.291878  144.616455   90.254265  ...
#
#    feature_13  feature_14  feature_15  feature_16  feature_17  feature_18  \
# 0  101.537338  526.225403  950.598267  317.534698   87.328026  908.293213
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40952 entries, 0 to 40951
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Time        40952 non-null  object
#  1   feature_01  40952 non-null  float64
#  2   feature_02  40952 non-null  float64
#  3   feature_03  40952 non-null  float64
#  4   feature_04  40952 non-null  float64
#  5   feature_05  40952 non-null  float64
#  6   feature_06  40952 non-null  float64
#  7   feature_07  40952 non-null  float64
#  8   feature_08  40952 non-null  float64
#  9   feature_09  40952 non-null  float64
#  10  feature_10  40952 non-null  float64
#  11  feature_11  40952 non-null  float64
#  12  feature_12  40952 non-null  float64
#  13  feature_13  40952 non-null  float64
#  14  feature_14  40952 non-null  float64
#  15  feature_15  40952 non-null  float64
#  16  feature_16  40952 non-null  float64
#  17  feature_17  40952 non-null  float64
# ...

# %%
data.describe()
# Out:
#          feature_01    feature_02    feature_03    feature_04    feature_05  \
# count  40952.000000  40952.000000  40952.000000  40952.000000  40952.000000
# mean    3902.156877    296.077828    152.886518     64.260022    120.809209
# std     3273.622302    195.739376    116.615331     47.732196    119.596579
# min        0.000000      0.000000      0.000000      0.010820      0.000000
# 25%        0.000000      0.000000      0.000000     16.053831      0.000000
# 50%     5230.995606    405.170288    191.872559     80.515156     59.266491
# 75%     7016.287231    439.703980    240.944824    110.621801    244.118912
# max     7960.601074    710.868530    559.914551    135.429352    300.000000
#
#          feature_06    feature_07    feature_08    feature_09    feature_10  \
# count  40952.000000  40952.000000  40952.000000  40952.000000  40952.000000
# mean     511.819294     76.340845     93.026896     86.606632    674.524511
# ...

# %%
data["Time"] = pd.to_datetime(data["Time"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40952 entries, 0 to 40951
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Time        40952 non-null  datetime64[ns]
#  1   feature_01  40952 non-null  float64
#  2   feature_02  40952 non-null  float64
#  3   feature_03  40952 non-null  float64
#  4   feature_04  40952 non-null  float64
#  5   feature_05  40952 non-null  float64
#  6   feature_06  40952 non-null  float64
#  7   feature_07  40952 non-null  float64
#  8   feature_08  40952 non-null  float64
#  9   feature_09  40952 non-null  float64
#  10  feature_10  40952 non-null  float64
#  11  feature_11  40952 non-null  float64
#  12  feature_12  40952 non-null  float64
#  13  feature_13  40952 non-null  float64
#  14  feature_14  40952 non-null  float64
#  15  feature_15  40952 non-null  float64
#  16  feature_16  40952 non-null  float64
#  17  feature_17  40952 non-null  float64
# ...

# %%
plt.figure(figsize=(15, 10))

sns.boxplot(data=data.iloc[:, :-1], orient="h")

plt.title("Boxplot of All Features")
plt.xlabel("Values")
plt.show()

# %%
features = data.iloc[:,1:]

# Create figure
plt.figure(figsize=(20,60))

# Plot each feature
for i, col in enumerate(features.columns, 1):
    plt.subplot(11,2, i)   # 5 rows × 5 columns = 25 plots
    sns.boxplot(y=features[col])
    plt.title(col)
    plt.ylabel("")

plt.tight_layout()
plt.show()

# %% [markdown]
# | Feature    | Outliers   | Action        |
# | ---------- | ---------- | ------------- |
# | feature_01 | ❌ None     | Keep          |
# | feature_02 | ❌ None     | Keep          |
# | feature_03 | ❌ None     | Keep          |
# | feature_04 | ❌ None     | Keep          |
# | feature_05 | ❌ None     | Keep          |
# | feature_06 | ❌ None     | Keep          |
# | feature_07 | ✅ Few      | IQR Capping   |
# | feature_08 | ❌ None     | Keep          |
# | feature_09 | ✅ Many     | Winsorization |
# | feature_10 | ❌ None     | Keep          |
# | feature_11 | ✅ Few      | IQR Capping   |
# | feature_12 | ✅ Many     | Winsorization |
# | feature_13 | ✅ Moderate | IQR Capping   |
# | feature_14 | ✅ Many     | Winsorization |
# | feature_15 | ✅ Many     | Winsorization |
# | feature_16 | ✅ Few      | IQR Capping   |
# | feature_17 | ✅ Many     | Winsorization |
# | feature_18 | ✅ Many     | Winsorization |
# | feature_19 | ✅ Many     | Winsorization |
# | feature_20 | ❌ None     | Keep          |
# | feature_21 | ❌ None     | Keep          |
# | Target     | ❌ Leave    | Keep          |

# %% [markdown]
# 1. IQR Capping : Remove the value whihc is the out side of lower and upper boundy
#  - Interquartile Range  : (IQR):IQR= Q3−Q1​
#  - Lower Boundary, Upper Boundary​
#
# 2. Percentile Capping : Remove the value whihc is out side of this boundy
#  - 1st Percentile , 99th Percentile
#  - 5th Percentile , 95th Percentile
#
# 3. Winsorization : Replace the value whihc is out side of this boundy
#  - 1st Percentile , 99th Percentile
#  - 5th Percentile , 95th Percentile

# %%
# Feature columns
X = data.iloc[:, 1:-1]
y = data["target"]

# %%
# Figure size
plt.figure(figsize=(20, 20))

# Plot each feature vs target
for i, col in enumerate(X.columns, 1):
    plt.subplot(5, 5, i)
    sns.regplot(
        x=X[col],
        y=y,
        scatter_kws={"s": 20, "alpha": 0.6},
        line_kws={"color": "red"}
    )
    plt.title(f"{col} vs {y.name}")

plt.tight_layout()
plt.show()

# %%
data.isnull().sum()
# Out:
# Time          0
# feature_01    0
# feature_02    0
# feature_03    0
# feature_04    0
# feature_05    0
# feature_06    0
# feature_07    0
# feature_08    0
# feature_09    0
# feature_10    0
# feature_11    0
# feature_12    0
# feature_13    0
# feature_14    0
# feature_15    0
# feature_16    0
# feature_17    0
# feature_18    0
# feature_19    0
# feature_20    0
# feature_21    0
# target        0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# first check wheter we can apply the linner regration onthis data set using correlation method
new_data = data.iloc[:, 1:]
plt.figure(figsize=(20, 20))

sns.heatmap(
    new_data.corr(),
    annot=True,
    annot_kws={"size":12}   # Smaller annotation text
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %%
x_new = new_data.iloc[:,:-1]
y_new = new_data["target"]

# %%
sc = StandardScaler()
sc.fit(x_new)
x_new =pd.DataFrame(sc.transform(x_new),columns=x_new.columns)
x_new.head()
# Out:
#    feature_01  feature_02  feature_03  feature_04  feature_05  feature_06  \
# 0   -1.192014   -1.512631   -1.311049    1.152923   -1.010152   -1.535696
# 1   -1.192014   -1.512631   -1.311049    1.151535   -1.010152   -1.535696
# 2   -1.192014   -1.512631   -1.311049    1.152993   -1.010152   -1.535696
# 3   -1.192014   -1.512631   -1.311049    1.156294   -1.010152   -1.535696
# 4   -1.192014   -1.512631   -1.311049    1.155368   -1.010152   -1.535696
#
#    feature_07  feature_08  feature_09  feature_10  ...  feature_12  \
# 0    0.727854    0.746399    0.323188    0.632291  ...    0.484426
# 1   -1.723771   -1.668502   -2.040320    0.632092  ...   -0.491015
# 2    0.537980    0.297736   -2.040320    0.632707  ...   -0.670298
# 3    0.429727    0.807238   -0.380365    0.632497  ...   -1.543872
# 4    0.202574    0.929331    0.086048    0.632707  ...    0.477814
#
#    feature_13  feature_14  feature_15  feature_16  feature_17  feature_18  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x_new,y_new,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr_score = lr.score(x_test,y_test)*100

# %%
lr.coef_
# Out:
# array([ 279.46318365,  449.27247291, -218.16580437,   13.06937927,
#         180.12308465,  315.26641832,   52.46052913,  226.30072285,
#         147.27907663,   60.64223901,   43.20179733,   11.35132844,
#          63.43574929,   83.95625809,   60.67223659,  -78.64064911,
#          41.48420358,   24.78562304,  -16.13578153,  108.54782865,
#         102.67678049])

# %%
plt.figure(figsize=(18,6))

plt.bar(x_new.columns, lr.coef_)

plt.xticks(rotation=45,fontsize = 12)
plt.tight_layout()
plt.title("Linear Regration")
plt.ylabel("coffecent")
plt.xlabel("name of feature")
plt.show()

# %%
print(f"""MSE :{mean_squared_error(y_test,lr.predict(x_test))}
\nMAE: {mean_absolute_error(y_test,lr.predict(x_test))}
\nRMSE: {np.sqrt(mean_squared_error(y_test,lr.predict(x_test)))}""")
# Out:
# MSE :318286.26429316314
#
# MAE: 362.2784077234802
#
# RMSE: 564.1686488038512

# %%
la = Lasso(alpha=0.5)
la.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.5)

# %%
la_score = la.score(x_test,y_test)*100

# %%
plt.figure(figsize=(18,5))

plt.bar(x_new.columns,la.coef_)
plt.xticks(rotation=45,fontsize = 12)
plt.title("Lasso")
plt.ylabel("coffecent")
plt.show()

# %%
# X locations for the bars
x = np.arange(len(x_new.columns))
width = 0.4

plt.figure(figsize=(18,6))

# Linear Regression
plt.bar(x - width/2, lr.coef_, width=width, label='Linear Regression')

# Lasso
plt.bar(x + width/2, la.coef_, width=width, label='Lasso')

plt.xticks(x, x_new.columns, rotation=45, ha='right', fontsize=11)

plt.xlabel("Features")
plt.ylabel("Coefficient")
plt.title("Linear Regression vs Lasso Coefficients")

plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
print(f"""MSE :{mean_squared_error(y_test,la.predict(x_test))}
\nMAE: {mean_absolute_error(y_test,la.predict(x_test))}
\nRMSE: {np.sqrt(mean_squared_error(y_test,la.predict(x_test)))}""")
# Out:
# MSE :318295.1629679694
#
# MAE: 362.16437638103304
#
# RMSE: 564.1765352865798

# %%
# Ridge

ri = Ridge(alpha=10)

# %%
ri.fit(x_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
ri_score = ri.score(x_test,y_test)*100

# %%
print(f"LinearRegression : {lr_score} \nLasso : {la_score} \nRidge : {ri_score}")
# Out:
# LinearRegression : 80.01356528145172
# Lasso : 80.01300649898747
# Ridge : 80.01358051532223

# %%
# X locations for the bars
x = np.arange(len(x_new.columns))
width = 0.40

plt.figure(figsize=(18,6))

# Linear Regression
plt.bar(x - width, lr.coef_, width=width, label='Linear Regression')

# Lasso
plt.bar(x, la.coef_, width=width, label='Lasso')

plt.bar(x + width, ri.coef_, width=width, label='Ridge')

plt.xticks(x, x_new.columns, rotation=45, ha='right', fontsize=11)

plt.xlabel("Features")
plt.ylabel("Coefficient")
plt.title("Linear Regression vs Lasso vs Ridge Coefficients")

plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
print(f"""MSE :{mean_squared_error(y_test,ri.predict(x_test))}
\nMAE: {mean_absolute_error(y_test,ri.predict(x_test))}
\nRMSE: {np.sqrt(mean_squared_error(y_test,ri.predict(x_test)))}""")
# Out:
# MSE :318286.0216920285
#
# MAE: 362.28140542168586
#
# RMSE: 564.1684337961744

# %%
#comparision of Coffecient of each with data frame
coff_data = pd.DataFrame({"col_name":x_new.columns,"LinearRegression":lr.coef_,"Lasso":la.coef_,"Ridge":ri.coef_})
coff_data
# Out:
#       col_name  LinearRegression       Lasso       Ridge
# 0   feature_01        279.463184  277.252639  278.973599
# 1   feature_02        449.272473  439.315321  446.666820
# 2   feature_03       -218.165804 -205.537976 -215.512410
# 3   feature_04         13.069379   12.772752   13.114632
# 4   feature_05        180.123085  177.996728  179.867317
# 5   feature_06        315.266418  316.209075  315.882205
# 6   feature_07         52.460529   52.697088   52.779162
# 7   feature_08        226.300723  224.433009  225.891982
# 8   feature_09        147.279077  150.433617  147.365578
# 9   feature_10         60.642239   61.031443   60.696325
# 10  feature_11         43.201797   39.282128   43.018654
# 11  feature_12         11.351328   12.334928   11.693565
# 12  feature_13         63.435749   57.708704   63.189206
# 13  feature_14         83.956258   82.400029   83.631397
# 14  feature_15         60.672237   61.776923   60.961123
# ...

# %% [markdown]
# ## Data Cleaning for outlier

# %%
iqr_cols = data[['feature_07','feature_11','feature_13','feature_16']]
iqr_cols.head()
# Out:
#    feature_07  feature_11  feature_13  feature_16
# 0  108.502075   77.208092  101.537338  317.534698
# 1    0.173611   71.445404   87.574669  219.791656
# 2  100.112236   25.062750   67.657333  158.854156
# 3   95.328934   51.258911   94.453339  179.861099
# 4   85.291878   70.758461   96.096001  278.645813

# %%
# Apply IQR Capping
for col in iqr_cols:

    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    data[col] = np.where(
        data[col] < lower_limit,
        lower_limit,
        np.where(
            data[col] > upper_limit,
            upper_limit,
            data[col]
        )
    )

# %%
iqr_cols.shape
# Out:
# (40952, 4)
